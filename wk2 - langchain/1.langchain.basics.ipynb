# %%
# %run ../shared_notebook_setup.py

# %% [markdown]
# ### 2. Developing using Langchain API

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model=DATABRICKS_MODEL,
    api_key=DATABRICKS_TOKEN,
    base_url=f"{DATABRICKS_HOST}/serving-endpoints",
)

msg = llm.invoke("What is Python in one sentence?")
print(json.dumps(msg.content, indent=2))
# Out:
# [
#   {
#     "type": "reasoning",
#     "summary": [
#       {
#         "type": "summary_text",
#         "text": "Thinking Process:\n\n1.  **Analyze the Request:**\n    *   Target: Python (the programming language).\n    *   Constraint: One sentence.\n    *   Goal: Define it accurately and concisely.\n\n2.  **Identify Key Characteristics of Python:**\n    *   High-level programming language.\n    *   Interpreted (not compiled like C++).\n    *   General-purpose (used for web, data science, AI, scripting, etc.).\n    *   Known for readability and simple syntax.\n    *   Created by Guido van Rossum.\n\n3.  **Draft Initial Sentences:**\n    *   Python is a high-level programming language known for its simplicity.\n    *   Python is a popular interpreted, high-level, general-purpose programming language.\n    *   Python is a high-level programming language that is widely used for artificial intelligence and web development.\n    *   Python is a programming language that emphasizes code readability and efficiency.\n\n4.  **Select the Best Definition:**\n    *   The second draft (\"Python is a popular interpreted, high-level, general-purpose programming language\") is the most standard technical definition.\n    *   However, mentioning its readability or widespread use adds context without breaking the constraint.\n    *   Let's aim for clarity and completeness within one sentence.\n\n5.  **Refine for Conciseness and Impact:**\n    *   \"Python is a high-level, interpreted, general-purpose programming language known for its clear syntax and versatility.\"\n    *   \"Python is a popular, high-level programming language designed for readability and used across various fields from web development to data science.\"\n\n6.  **Final Polish:**\n    *   \"Python is a high-level, interpreted, general-purpose programming language known for its simple syntax and versatility.\" (This covers the key technical aspects and its main selling point).\n\n7.  **Final Check against Constraints:**\n    *   Is it about Python? Yes.\n    *   Is it one sentence? Yes.\n\n8.  **Output Generation:** (Selecting the most balanced definition).\n    \"Python is a high-level, interpreted, general-purpose programming language known for its clear syntax and versatility.\" or simply \"Python is a popular, high-level programming language known for its simplicity and use in everything from web development to artificial intelligence.\"\n\n    Let's go with the most encompassing one.\n    \"Python is a high-level, interpreted, general-purpose programming language celebrated for its readable syntax and versatility across fields like web development, data science, and automation.\" -> A bit long.\n\n    Simpler: \"Python is a high-level, interpreted general-purpose programming language known for its clear syntax and widespread use in software development, data science, and artificial intelligence.\"\n\n    Even simpler: \"Python is a popular, high-level programming language known for its readability and versatility.\"\n\n    Let's stick to the core definition often used in documentation.\n    \"Python is a high-level, interpreted, general-purpose programming language known for its simplicity and readability.\"\n\n    Wait, I should make sure it captures its *utility* too.\n    \"Python is a high-level, interpreted programming language renowned for its clear syntax and versatility in fields ranging from web development to artificial intelligence.\"\n\n    This is one sentence. It's accurate.\n\n    Let's try to be even more concise.\n    \"Python is a high-level, general-purpose programming language known for its readable syntax and versatility in software development.\"\n\n    Okay, I will choose a version that balances technical accuracy with common understanding.\n\n    \"Python is a high-level, interpreted, general-purpose programming language known for its simple syntax and versatility across various fields.\"\n\n9.  **Final Decision:**\n    \"Python is a high-level, interpreted, general-purpose programming language known for its clear syntax and versatility.\"\n\n ...
#       }
#     ]
#   },
#   {
#     "type": "text",
#     "text": "Python is a high-level, interpreted, general-purpose programming language known for its clear syntax and versatility across fields like web development, data science, and artificial intelligence."
#   }
# ]

# %% [markdown]
# ### 3. Creating Basic Chain using Langchain Expression Language (LCEL)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in 3 short bullet points."
)

chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "LangChain"})
print(result)
# Out:
# *   It is an open-source framework for building applications powered by large language models (LLMs).
# *   It connects LLMs to external data sources, tools, and memory to enable context-aware interactions.
# *   It simplifies complex workflows by chaining together components like prompts, agents, and logic.

# %%
# Reusing existing template and chain with different topics
for t in ["LangChain", "Prompt Engineering", "Vector Databases"]:
    print(chain.invoke({"topic": t}))
    print("-" * 60)
# Out:
# *   **Framework for LLMs:** An open-source library designed to simplify building applications powered by large language models.
# *   **Chaining Capabilities:** Enables linking prompts, data sources, and external tools into cohesive workflows to handle complex tasks.
# *   **Pre-built Components:** Accelerates development with ready-made modules for memory, agents, and document processing.
# ------------------------------------------------------------
# *   **Crafting Instructions:** Designing precise text inputs to guide an AI’s behavior and desired outcomes.
# *   **Optimizing Results:** Using techniques to improve the accuracy, tone, and format of generated responses.
# *   **Enhancing Performance:** Achieving better output quality without needing to retrain or modify the underlying model.
# ------------------------------------------------------------
# *   **Store data as vectors:** They save complex, unstructured data (like text or images) as numerical embeddings rather than traditional rows and columns.
# *   **Enable semantic search:** They allow for rapid similarity searches based on meaning and context, not just exact keyword matching.
# *   **Power AI applications:** They are essential infrastructure for modern machine learning tasks, such as LLMs, chatbots, and recommendation systems.
# ------------------------------------------------------------
